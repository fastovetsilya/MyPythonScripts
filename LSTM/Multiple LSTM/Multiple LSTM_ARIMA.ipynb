# %%
# https://machinelearningmastery.com/multivariate-time-series-forecasting-lstms-keras/
#https://pyramid-arima.readthedocs.io/en/latest/_submodules/arima.html
import numpy
from numpy import newaxis
import matplotlib.pyplot as plt
import pandas
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from sklearn import preprocessing 
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from pyramid.arima import auto_arima

# %%
# load dataset
dataset = pandas.read_csv('URBN.csv', header=0, index_col=0)
values = dataset.values[1::, :]
values = numpy.flipud(values)
# specify columns to plot
groups = [0, 1, 2, 3, 4]
i = 1
# plot each column
plt.figure()
for group in groups:
	plt.subplot(len(groups), 1, i)
	plt.plot(values[:, group])
	plt.title(dataset.columns[group], y=0.5, loc='right')
	i += 1
plt.show()

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = pandas.DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = pandas.concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg
 
# integer encode direction
encoder = preprocessing.LabelEncoder()
values[:,4] = encoder.fit_transform(values[:,4])
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, 1, 1)
# drop columns we don't want to predict
reframed.drop(reframed.columns[[6,7,8,9]], axis=1, inplace=True)
print(reframed.head())
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)   var1(t)
# 1   0.272072   0.060236   0.269197   0.267930   0.345133  0.291441
# 2   0.291441   0.053993   0.267873   0.263870   0.349558  0.292793
# 3   0.292793   0.049257   0.284643   0.272891   0.393805  0.273423
# 4   0.273423   0.054651   0.287732   0.271087   0.358407  0.286937
# 5   0.286937   0.061345   0.270962   0.266351   0.362832  0.290090

# %%
# split into train and test sets
values = reframed.values
n_train_hours = 170
train = values[:n_train_hours, :]
test = values[n_train_hours:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (170, 1, 5) (170,) (80, 1, 5) (80,)

# %%
# design network
model = Sequential()
model.add(LSTM(300, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dropout(0.3))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
history = model.fit(train_X, train_y, epochs=100, batch_size=15, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Train on 170 samples, validate on 80 samples
# Epoch 1/100
#  - 2s - loss: 0.1835 - val_loss: 0.5234
# Epoch 2/100
#  - 0s - loss: 0.0775 - val_loss: 0.2616
# Epoch 3/100
#  - 0s - loss: 0.0745 - val_loss: 0.1628
# Epoch 4/100
#  - 0s - loss: 0.0644 - val_loss: 0.1843
# Epoch 5/100
#  - 0s - loss: 0.0460 - val_loss: 0.1324
# Epoch 6/100
#  - 0s - loss: 0.0404 - val_loss: 0.0782
# Epoch 7/100
#  - 0s - loss: 0.0333 - val_loss: 0.0521
# Epoch 8/100
#  - 0s - loss: 0.0252 - val_loss: 0.0333
# Epoch 9/100
#  - 0s - loss: 0.0271 - val_loss: 0.0413
# Epoch 10/100
#  - 0s - loss: 0.0256 - val_loss: 0.0367
# Epoch 11/100
#  - 0s - loss: 0.0279 - val_loss: 0.0446
# Epoch 12/100
#  - 0s - loss: 0.0240 - val_loss: 0.0386
# Epoch 13/100
#  - 0s - loss: 0.0282 - val_loss: 0.0328
# Epoch 14/100
#  - 0s - loss: 0.0264 - val_loss: 0.0328
# Epoch 15/100
#  - 0s - loss: 0.0267 - val_loss: 0.0325
# Epoch 16/100
#  - 0s - loss: 0.0283 - val_loss: 0.0388
# Epoch 17/100
#  - 0s - loss: 0.0256 - val_loss: 0.0380
# Epoch 18/100
#  - 0s - loss: 0.0256 - val_loss: 0.0459
# Epoch 19/100
#  - 0s - loss: 0.0269 - val_loss: 0.0386
# Epoch 20/100
#  - 0s - loss: 0.0270 - val_loss: 0.0354
# Epoch 21/100
#  - 0s - loss: 0.0250 - val_loss: 0.0346
# Epoch 22/100
#  - 0s - loss: 0.0250 - val_loss: 0.0352
# Epoch 23/100
#  - 0s - loss: 0.0301 - val_loss: 0.0432
# Epoch 24/100
#  - 0s - loss: 0.0285 - val_loss: 0.0429
# Epoch 25/100
#  - 0s - loss: 0.0273 - val_loss: 0.0380
# Epoch 26/100
#  - 0s - loss: 0.0333 - val_loss: 0.0328
# Epoch 27/100
#  - 0s - loss: 0.0323 - val_loss: 0.0415
# Epoch 28/100
#  - 0s - loss: 0.0356 - val_loss: 0.0334
# Epoch 29/100
#  - 0s - loss: 0.0295 - val_loss: 0.0496
# Epoch 30/100
#  - 0s - loss: 0.0346 - val_loss: 0.0328
# Epoch 31/100
#  - 0s - loss: 0.0300 - val_loss: 0.0556
# Epoch 32/100
#  - 0s - loss: 0.0304 - val_loss: 0.0329
# Epoch 33/100
#  - 0s - loss: 0.0251 - val_loss: 0.0432
# Epoch 34/100
#  - 0s - loss: 0.0298 - val_loss: 0.0330
# Epoch 35/100
#  - 0s - loss: 0.0262 - val_loss: 0.0394
# Epoch 36/100
#  - 0s - loss: 0.0256 - val_loss: 0.0395
# Epoch 37/100
#  - 0s - loss: 0.0241 - val_loss: 0.0351
# Epoch 38/100
#  - 0s - loss: 0.0237 - val_loss: 0.0406
# Epoch 39/100
#  - 0s - loss: 0.0244 - val_loss: 0.0452
# Epoch 40/100
#  - 0s - loss: 0.0235 - val_loss: 0.0518
# Epoch 41/100
#  - 0s - loss: 0.0239 - val_loss: 0.0437
# Epoch 42/100
#  - 0s - loss: 0.0241 - val_loss: 0.0465
# Epoch 43/100
#  - 0s - loss: 0.0242 - val_loss: 0.0352
# Epoch 44/100
#  - 0s - loss: 0.0246 - val_loss: 0.0367
# Epoch 45/100
#  - 0s - loss: 0.0246 - val_loss: 0.0439
# Epoch 46/100
#  - 0s - loss: 0.0248 - val_loss: 0.0451
# Epoch 47/100
#  - 0s - loss: 0.0244 - val_loss: 0.0435
# Epoch 48/100
#  - 0s - loss: 0.0247 - val_loss: 0.0414
# Epoch 49/100
#  - 0s - loss: 0.0234 - val_loss: 0.0442
# Epoch 50/100
#  - 0s - loss: 0.0235 - val_loss: 0.0444
# Epoch 51/100
#  - 0s - loss: 0.0240 - val_loss: 0.0470
# Epoch 52/100
#  - 0s - loss: 0.0259 - val_loss: 0.0458
# Epoch 53/100
#  - 0s - loss: 0.0235 - val_loss: 0.0460
# Epoch 54/100
#  - 0s - loss: 0.0254 - val_loss: 0.0410
# Epoch 55/100
#  - 0s - loss: 0.0238 - val_loss: 0.0350
# Epoch 56/100
#  - 0s - loss: 0.0255 - val_loss: 0.0498
# Epoch 57/100
#  - 0s - loss: 0.0284 - val_loss: 0.0441
# Epoch 58/100
#  - 0s - loss: 0.0289 - val_loss: 0.0470
# Epoch 59/100
#  - 0s - loss: 0.0290 - val_loss: 0.0513
# Epoch 60/100
#  - 0s - loss: 0.0309 - val_loss: 0.0386
# Epoch 61/100
#  - 0s - loss: 0.0215 - val_loss: 0.0403
# Epoch 62/100
#  - 0s - loss: 0.0249 - val_loss: 0.0445
# Epoch 63/100
#  - 0s - loss: 0.0245 - val_loss: 0.0458
# Epoch 64/100
#  - 0s - loss: 0.0243 - val_loss: 0.0425
# Epoch 65/100
#  - 0s - loss: 0.0273 - val_loss: 0.0459
# Epoch 66/100
#  - 0s - loss: 0.0245 - val_loss: 0.0446
# Epoch 67/100
#  - 0s - loss: 0.0211 - val_loss: 0.0399
# Epoch 68/100
#  - 0s - loss: 0.0242 - val_loss: 0.0328
# Epoch 69/100
#  - 0s - loss: 0.0260 - val_loss: 0.0393
# Epoch 70/100
#  - 0s - loss: 0.0220 - val_loss: 0.0459
# Epoch 71/100
#  - 0s - loss: 0.0236 - val_loss: 0.0458
# Epoch 72/100
#  - 0s - loss: 0.0245 - val_loss: 0.0374
# Epoch 73/100
#  - 0s - loss: 0.0241 - val_loss: 0.0355
# Epoch 74/100
#  - 0s - loss: 0.0222 - val_loss: 0.0390
# Epoch 75/100
#  - 0s - loss: 0.0274 - val_loss: 0.0362
# Epoch 76/100
#  - 0s - loss: 0.0225 - val_loss: 0.0524
# Epoch 77/100
#  - 0s - loss: 0.0233 - val_loss: 0.0495
# Epoch 78/100
#  - 0s - loss: 0.0250 - val_loss: 0.0399
# Epoch 79/100
#  - 0s - loss: 0.0232 - val_loss: 0.0324
# Epoch 80/100
#  - 0s - loss: 0.0241 - val_loss: 0.0360
# Epoch 81/100
#  - 0s - loss: 0.0258 - val_loss: 0.0364
# Epoch 82/100
#  - 0s - loss: 0.0234 - val_loss: 0.0467
# Epoch 83/100
#  - 0s - loss: 0.0245 - val_loss: 0.0388
# Epoch 84/100
#  - 0s - loss: 0.0229 - val_loss: 0.0440
# Epoch 85/100
#  - 0s - loss: 0.0243 - val_loss: 0.0354
# Epoch 86/100
#  - 0s - loss: 0.0260 - val_loss: 0.0353
# Epoch 87/100
#  - 0s - loss: 0.0241 - val_loss: 0.0361
# Epoch 88/100
#  - 0s - loss: 0.0230 - val_loss: 0.0341
# Epoch 89/100
#  - 0s - loss: 0.0223 - val_loss: 0.0389
# Epoch 90/100
#  - 0s - loss: 0.0236 - val_loss: 0.0444
# Epoch 91/100
#  - 0s - loss: 0.0237 - val_loss: 0.0495
# Epoch 92/100
#  - 0s - loss: 0.0225 - val_loss: 0.0401
# Epoch 93/100
#  - 0s - loss: 0.0229 - val_loss: 0.0362
# Epoch 94/100
#  - 0s - loss: 0.0225 - val_loss: 0.0450
# Epoch 95/100
#  - 0s - loss: 0.0283 - val_loss: 0.0363
# Epoch 96/100
#  - 0s - loss: 0.0282 - val_loss: 0.0483
# Epoch 97/100
#  - 0s - loss: 0.0234 - val_loss: 0.0325
# Epoch 98/100
#  - 0s - loss: 0.0233 - val_loss: 0.0344
# Epoch 99/100
#  - 0s - loss: 0.0237 - val_loss: 0.0499
# Epoch 100/100
#  - 0s - loss: 0.0247 - val_loss: 0.0368

# %%
# plot history
plt.figure(figsize=(10,10))
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
# invert scaling for forecast
inv_yhat = numpy.concatenate((yhat, test_X[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = numpy.concatenate((test_y, test_X[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = math.sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 1.018

# %%
plt.figure(figsize=(20,10))
plt.plot(inv_y)
plt.plot(inv_yhat)
plt.show()

# %%
# Test on the whole dataset: prepare data
values2 = reframed.values
train_X2, train_y2 = values2[:, :-1], values2[:, -1]
train_X2 = train_X2.reshape((train_X2.shape[0], 1, train_X2.shape[1]))
print(train_X2.shape, train_y2.shape)
# Out:
# (250, 1, 5) (250,)

# %%
# Test o the whole dataset: design network
model2 = Sequential()
model2.add(LSTM(300, input_shape=(train_X2.shape[1], train_X2.shape[2])))
model.add(Dropout(0.3))
model2.add(Dense(1))
model2.compile(loss='mae', optimizer='adam')
# fit network
history = model2.fit(train_X2, train_y2, epochs=100, batch_size=15, verbose=2, shuffle=False)
# Out:
# Epoch 1/100
#  - 2s - loss: 0.2693
# Epoch 2/100
#  - 0s - loss: 0.0907
# Epoch 3/100
#  - 0s - loss: 0.0986
# Epoch 4/100
#  - 0s - loss: 0.0788
# Epoch 5/100
#  - 0s - loss: 0.0388
# Epoch 6/100
#  - 0s - loss: 0.0290
# Epoch 7/100
#  - 0s - loss: 0.0294
# Epoch 8/100
#  - 0s - loss: 0.0300
# Epoch 9/100
#  - 0s - loss: 0.0293
# Epoch 10/100
#  - 0s - loss: 0.0288
# Epoch 11/100
#  - 0s - loss: 0.0294
# Epoch 12/100
#  - 0s - loss: 0.0295
# Epoch 13/100
#  - 0s - loss: 0.0298
# Epoch 14/100
#  - 0s - loss: 0.0298
# Epoch 15/100
#  - 0s - loss: 0.0293
# Epoch 16/100
#  - 0s - loss: 0.0296
# Epoch 17/100
#  - 0s - loss: 0.0301
# Epoch 18/100
#  - 0s - loss: 0.0301
# Epoch 19/100
#  - 0s - loss: 0.0286
# Epoch 20/100
#  - 0s - loss: 0.0285
# Epoch 21/100
#  - 0s - loss: 0.0298
# Epoch 22/100
#  - 0s - loss: 0.0293
# Epoch 23/100
#  - 0s - loss: 0.0298
# Epoch 24/100
#  - 0s - loss: 0.0300
# Epoch 25/100
#  - 0s - loss: 0.0282
# Epoch 26/100
#  - 0s - loss: 0.0296
# Epoch 27/100
#  - 0s - loss: 0.0298
# Epoch 28/100
#  - 0s - loss: 0.0280
# Epoch 29/100
#  - 0s - loss: 0.0299
# Epoch 30/100
#  - 0s - loss: 0.0299
# Epoch 31/100
#  - 0s - loss: 0.0267
# Epoch 32/100
#  - 0s - loss: 0.0278
# Epoch 33/100
#  - 0s - loss: 0.0320
# Epoch 34/100
#  - 0s - loss: 0.0297
# Epoch 35/100
#  - 0s - loss: 0.0260
# Epoch 36/100
#  - 0s - loss: 0.0281
# Epoch 37/100
#  - 0s - loss: 0.0320
# Epoch 38/100
#  - 0s - loss: 0.0262
# Epoch 39/100
#  - 0s - loss: 0.0258
# Epoch 40/100
#  - 0s - loss: 0.0287
# Epoch 41/100
#  - 0s - loss: 0.0304
# Epoch 42/100
#  - 0s - loss: 0.0257
# Epoch 43/100
#  - 0s - loss: 0.0272
# Epoch 44/100
#  - 0s - loss: 0.0326
# Epoch 45/100
#  - 0s - loss: 0.0310
# Epoch 46/100
#  - 0s - loss: 0.0250
# Epoch 47/100
#  - 0s - loss: 0.0267
# Epoch 48/100
#  - 0s - loss: 0.0307
# Epoch 49/100
#  - 0s - loss: 0.0306
# Epoch 50/100
#  - 0s - loss: 0.0256
# Epoch 51/100
#  - 0s - loss: 0.0261
# Epoch 52/100
#  - 0s - loss: 0.0305
# Epoch 53/100
#  - 0s - loss: 0.0293
# Epoch 54/100
#  - 0s - loss: 0.0249
# Epoch 55/100
#  - 0s - loss: 0.0257
# Epoch 56/100
#  - 0s - loss: 0.0287
# Epoch 57/100
#  - 0s - loss: 0.0289
# Epoch 58/100
#  - 0s - loss: 0.0246
# Epoch 59/100
#  - 0s - loss: 0.0247
# Epoch 60/100
#  - 0s - loss: 0.0281
# Epoch 61/100
#  - 0s - loss: 0.0270
# Epoch 62/100
#  - 0s - loss: 0.0268
# Epoch 63/100
#  - 0s - loss: 0.0298
# Epoch 64/100
#  - 0s - loss: 0.0277
# Epoch 65/100
#  - 0s - loss: 0.0243
# Epoch 66/100
#  - 0s - loss: 0.0244
# Epoch 67/100
#  - 0s - loss: 0.0261
# Epoch 68/100
#  - 0s - loss: 0.0281
# Epoch 69/100
#  - 0s - loss: 0.0292
# Epoch 70/100
#  - 0s - loss: 0.0242
# Epoch 71/100
#  - 0s - loss: 0.0241
# Epoch 72/100
#  - 0s - loss: 0.0245
# Epoch 73/100
#  - 0s - loss: 0.0274
# Epoch 74/100
#  - 0s - loss: 0.0312
# Epoch 75/100
#  - 0s - loss: 0.0250
# Epoch 76/100
#  - 0s - loss: 0.0238
# Epoch 77/100
#  - 0s - loss: 0.0254
# Epoch 78/100
#  - 0s - loss: 0.0270
# Epoch 79/100
#  - 0s - loss: 0.0306
# Epoch 80/100
#  - 0s - loss: 0.0254
# Epoch 81/100
#  - 0s - loss: 0.0242
# Epoch 82/100
#  - 0s - loss: 0.0271
# Epoch 83/100
#  - 0s - loss: 0.0269
# Epoch 84/100
#  - 0s - loss: 0.0276
# Epoch 85/100
#  - 0s - loss: 0.0281
# Epoch 86/100
#  - 0s - loss: 0.0250
# Epoch 87/100
#  - 0s - loss: 0.0256
# Epoch 88/100
#  - 0s - loss: 0.0261
# Epoch 89/100
#  - 0s - loss: 0.0273
# Epoch 90/100
#  - 0s - loss: 0.0241
# Epoch 91/100
#  - 0s - loss: 0.0248
# Epoch 92/100
#  - 0s - loss: 0.0251
# Epoch 93/100
#  - 0s - loss: 0.0251
# Epoch 94/100
#  - 0s - loss: 0.0237
# Epoch 95/100
#  - 0s - loss: 0.0231
# Epoch 96/100
#  - 0s - loss: 0.0233
# Epoch 97/100
#  - 0s - loss: 0.0269
# Epoch 98/100
#  - 0s - loss: 0.0254
# Epoch 99/100
#  - 0s - loss: 0.0311
# Epoch 100/100
#  - 0s - loss: 0.0295

# %%
# make predictions
yhat2 = model2.predict(train_X2)
train_X2 = train_X2.reshape((train_X2.shape[0], train_X2.shape[2]))
inv_yhat2 = numpy.concatenate((yhat2, train_X2[:, 1:]), axis=1)
inv_yhat2 = scaler.inverse_transform(inv_yhat2)
inv_yhat2 = inv_yhat2[:,0]

# %%
plt.figure(figsize=(20,10))
plt.plot(numpy.flipud(dataset.values[1::, 0]))
plt.plot(inv_yhat2)

# %%
numpy.savetxt("LSTM_Predicted.csv", inv_yhat2, delimiter=",")

# %%
stepwise_model = auto_arima(inv_yhat2, start_p=1, start_q=1,
                           max_p=3, max_q=3, m=7,
                           start_P=0, seasonal=True,
                           d=1, D=1, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
# Out:
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 7); AIC=419.547, BIC=437.155, Fit time=1.145 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 7); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 7); AIC=487.232, BIC=501.318, Fit time=0.275 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 7); AIC=417.638, BIC=431.724, Fit time=0.512 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 1, 7); AIC=417.915, BIC=435.522, Fit time=0.730 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 0, 7); AIC=536.633, BIC=547.197, Fit time=0.165 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 2, 7); AIC=417.847, BIC=435.455, Fit time=0.986 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 2, 7); AIC=419.062, BIC=440.191, Fit time=1.876 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 1, 7); AIC=417.761, BIC=428.326, Fit time=0.317 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 1, 1, 7); AIC=419.523, BIC=437.131, Fit time=0.686 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 1, 7); AIC=421.548, BIC=442.677, Fit time=0.772 seconds
# Total fit time: 7.469 seconds

# %%
print(stepwise_model.aic())
# Out:
# 417.638491983

# %%
n_periods = 15
future_forecast = stepwise_model.predict(n_periods=n_periods)
print(future_forecast)
trainPredict2full = numpy.append(inv_yhat2,future_forecast)
# Out:
# [ 38.69678198  38.80367997  38.82320294  39.07010274  39.23933782
#   39.56137409  39.71596822  39.79449552  39.90701094  39.93215134
#   40.18466857  40.35952107  40.68717477  40.84738632  40.93153105]

# %%
plt.figure(figsize=(20,10))
plt.plot(inv_yhat2)
plt.plot(trainPredict2full, '--')
plt.show()
