# %%
# https://machinelearningmastery.com/time-series-prediction-lstm-recurrent-neural-networks-python-keras/
#https://pyramid-arima.readthedocs.io/en/latest/_submodules/arima.html
import numpy
from numpy import newaxis
import matplotlib.pyplot as plt
import pandas
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from pyramid.arima import auto_arima

# %%
dataset = pandas.read_csv('HistoricalQuotes.csv', usecols=[1], engine='python', skipfooter=3)
dataset = numpy.flipud(dataset)[850::]
plt.figure(figsize=(10,5))
plt.plot(dataset)
plt.show()

# %%
# fix random seed for reproducibility
numpy.random.seed(7)

# %%
# load the dataset
dataset = pandas.read_csv('HistoricalQuotes.csv', usecols=[1], engine='python', skipfooter=3)
dataset = numpy.flipud(dataset)[850::]
#dataset = dataframe.values
dataset = dataset.astype('float32')

# %%
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# %%
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))
# Out:
# 273 135

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
# reshape into X=t and Y=t+1
look_back = 15
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# %%
trainX.shape
# Out:
# (257, 15)

# %%
# reshape input to be [samples, time steps, features]
trainX = numpy.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = numpy.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
trainX.shape
# Out:
# (257, 1, 15)

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(32, input_shape=(1, look_back)))
model.add(Dropout(0.3))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=50, batch_size=1, verbose=2)
# Out:
# Epoch 1/50
#  - 2s - loss: 0.0048
# Epoch 2/50
#  - 1s - loss: 0.0014
# Epoch 3/50
#  - 1s - loss: 0.0013
# Epoch 4/50
#  - 1s - loss: 9.6610e-04
# Epoch 5/50
#  - 1s - loss: 9.0999e-04
# Epoch 6/50
#  - 1s - loss: 8.9299e-04
# Epoch 7/50
#  - 1s - loss: 7.5477e-04
# Epoch 8/50
#  - 1s - loss: 7.2487e-04
# Epoch 9/50
#  - 1s - loss: 7.4297e-04
# Epoch 10/50
#  - 1s - loss: 7.0332e-04
# Epoch 11/50
#  - 1s - loss: 7.4876e-04
# Epoch 12/50
#  - 1s - loss: 6.3216e-04
# Epoch 13/50
#  - 1s - loss: 5.8389e-04
# Epoch 14/50
#  - 1s - loss: 6.0924e-04
# Epoch 15/50
#  - 1s - loss: 6.4876e-04
# Epoch 16/50
#  - 1s - loss: 5.1626e-04
# Epoch 17/50
#  - 1s - loss: 6.6346e-04
# Epoch 18/50
#  - 1s - loss: 6.8365e-04
# Epoch 19/50
#  - 1s - loss: 6.6316e-04
# Epoch 20/50
#  - 1s - loss: 6.0051e-04
# Epoch 21/50
#  - 1s - loss: 5.2146e-04
# Epoch 22/50
#  - 1s - loss: 6.4969e-04
# Epoch 23/50
#  - 1s - loss: 6.1033e-04
# Epoch 24/50
#  - 1s - loss: 6.1190e-04
# Epoch 25/50
#  - 1s - loss: 5.6043e-04
# Epoch 26/50
#  - 1s - loss: 5.2052e-04
# Epoch 27/50
#  - 1s - loss: 5.0113e-04
# Epoch 28/50
#  - 1s - loss: 4.9928e-04
# Epoch 29/50
#  - 1s - loss: 5.2306e-04
# Epoch 30/50
#  - 1s - loss: 4.5061e-04
# Epoch 31/50
#  - 1s - loss: 5.6128e-04
# Epoch 32/50
#  - 1s - loss: 5.2640e-04
# Epoch 33/50
#  - 1s - loss: 5.0433e-04
# Epoch 34/50
#  - 1s - loss: 4.7527e-04
# Epoch 35/50
#  - 1s - loss: 5.0899e-04
# Epoch 36/50
#  - 1s - loss: 5.2129e-04
# Epoch 37/50
#  - 1s - loss: 4.4432e-04
# Epoch 38/50
#  - 1s - loss: 5.3494e-04
# Epoch 39/50
#  - 1s - loss: 5.0401e-04
# Epoch 40/50
#  - 1s - loss: 4.6965e-04
# Epoch 41/50
#  - 1s - loss: 5.0803e-04
# Epoch 42/50
#  - 1s - loss: 4.9065e-04
# Epoch 43/50
#  - 1s - loss: 5.1293e-04
# Epoch 44/50
#  - 1s - loss: 4.2786e-04
# Epoch 45/50
#  - 1s - loss: 4.2621e-04
# Epoch 46/50
#  - 1s - loss: 4.4816e-04
# Epoch 47/50
#  - 1s - loss: 4.2636e-04
# Epoch 48/50
#  - 1s - loss: 4.9328e-04
# Epoch 49/50
#  - 1s - loss: 4.2306e-04
# Epoch 50/50
#  - 1s - loss: 4.8194e-04

# %%
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 3.80 RMSE
# Test Score: 9.40 RMSE

# %%
# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.figure(figsize=(20,10))
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
train2 = dataset
trainX2, trainY2 = create_dataset(train2, look_back)
trainX2 = numpy.reshape(trainX2, (trainX2.shape[0], 1, trainX2.shape[1]))
trainX2.shape, trainY2.shape
# Out:
# ((392, 1, 15), (392,))

# %%
model2 = Sequential()
model2.add(LSTM(32, input_shape=(1, look_back)))
model2.add(Dropout(0.3))
model2.add(Dense(1))
model2.compile(loss='mean_squared_error', optimizer='adam')
model2.fit(trainX2, trainY2, epochs=50, batch_size=1, verbose=2)
# Out:
# Epoch 1/50
#  - 2s - loss: 0.0109
# Epoch 2/50
#  - 1s - loss: 0.0015
# Epoch 3/50
#  - 1s - loss: 0.0015
# Epoch 4/50
#  - 1s - loss: 0.0015
# Epoch 5/50
#  - 1s - loss: 0.0012
# Epoch 6/50
#  - 1s - loss: 0.0012
# Epoch 7/50
#  - 1s - loss: 0.0012
# Epoch 8/50
#  - 1s - loss: 0.0012
# Epoch 9/50
#  - 1s - loss: 0.0011
# Epoch 10/50
#  - 1s - loss: 0.0010
# Epoch 11/50
#  - 1s - loss: 0.0011
# Epoch 12/50
#  - 1s - loss: 0.0010
# Epoch 13/50
#  - 1s - loss: 9.6405e-04
# Epoch 14/50
#  - 1s - loss: 9.1911e-04
# Epoch 15/50
#  - 1s - loss: 9.9600e-04
# Epoch 16/50
#  - 1s - loss: 9.2156e-04
# Epoch 17/50
#  - 1s - loss: 8.2532e-04
# Epoch 18/50
#  - 1s - loss: 8.5598e-04
# Epoch 19/50
#  - 1s - loss: 9.3849e-04
# Epoch 20/50
#  - 1s - loss: 8.0379e-04
# Epoch 21/50
#  - 1s - loss: 8.4818e-04
# Epoch 22/50
#  - 1s - loss: 9.0990e-04
# Epoch 23/50
#  - 1s - loss: 7.8535e-04
# Epoch 24/50
#  - 2s - loss: 8.5123e-04
# Epoch 25/50
#  - 1s - loss: 8.3725e-04
# Epoch 26/50
#  - 1s - loss: 8.3411e-04
# Epoch 27/50
#  - 1s - loss: 7.4855e-04
# Epoch 28/50
#  - 1s - loss: 7.7780e-04
# Epoch 29/50
#  - 1s - loss: 7.8147e-04
# Epoch 30/50
#  - 1s - loss: 7.9187e-04
# Epoch 31/50
#  - 1s - loss: 7.5230e-04
# Epoch 32/50
#  - 1s - loss: 8.0302e-04
# Epoch 33/50
#  - 1s - loss: 6.7464e-04
# Epoch 34/50
#  - 1s - loss: 7.3515e-04
# Epoch 35/50
#  - 1s - loss: 7.4181e-04
# Epoch 36/50
#  - 1s - loss: 9.2103e-04
# Epoch 37/50
#  - 2s - loss: 7.4496e-04
# Epoch 38/50
#  - 2s - loss: 8.8226e-04
# Epoch 39/50
#  - 1s - loss: 7.7792e-04
# Epoch 40/50
#  - 1s - loss: 6.8332e-04
# Epoch 41/50
#  - 1s - loss: 6.8009e-04
# Epoch 42/50
#  - 1s - loss: 7.5174e-04
# Epoch 43/50
#  - 1s - loss: 7.9327e-04
# Epoch 44/50
#  - 1s - loss: 7.3280e-04
# Epoch 45/50
#  - 1s - loss: 6.9963e-04
# Epoch 46/50
#  - 1s - loss: 6.4269e-04
# Epoch 47/50
#  - 1s - loss: 7.3887e-04
# Epoch 48/50
#  - 1s - loss: 7.1607e-04
# Epoch 49/50
#  - 1s - loss: 6.8127e-04
# Epoch 50/50
#  - 1s - loss: 7.4194e-04

# %%
# make predictions
trainPredict2 = model2.predict(trainX2)
# invert predictions
trainPredict2 = scaler.inverse_transform(trainPredict2)
trainY2 = scaler.inverse_transform([trainY2])
# calculate root mean squared error
trainScore2 = math.sqrt(mean_squared_error(trainY2, trainPredict2.T))
print('Train Score2: %.2f RMSE' % (trainScore2))
# Out:
# Train Score2: 7.98 RMSE

# %%
trainY2.shape, trainPredict2.shape
# Out:
# ((1, 392), (392, 1))

# %%
# shift train predictions for plotting
trainPredictPlot2 = numpy.empty_like(dataset)
trainPredictPlot2[:, :] = numpy.nan
trainPredictPlot2[look_back:len(trainPredict2)+look_back, :] = trainPredict2

# plot baseline and predictions
plt.figure(figsize=(20,10))
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot2)
plt.show()

# %%
import pandas as pd
#from plotly.plotly import plot_mpl
#from statsmodels.tsa.seasonal import seasonal_decompose

# %%
#trainPredict2 = pd.DataFrame(trainPredict2)
#result = seasonal_decompose(trainPredict2, model='multiplicative')
#fig = result.plot()
#plot_mpl(fig)

# %%
numpy.savetxt("LSTM_Predicted.csv", trainPredict2, delimiter=",")

# %%
stepwise_model = auto_arima(trainPredict2, start_p=1, start_q=1,
                           max_p=3, max_q=3, m=12,
                           start_P=0, seasonal=True,
                           d=1, D=1, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
# Out:
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=1731.325, BIC=1751.181, Fit time=2.951 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=1834.570, BIC=1850.455, Fit time=0.747 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=1738.380, BIC=1754.265, Fit time=2.524 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=1732.145, BIC=1755.973, Fit time=3.567 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=1920.221, BIC=1936.106, Fit time=0.428 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 2, 12); AIC=1732.144, BIC=1755.972, Fit time=4.911 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=1734.147, BIC=1761.946, Fit time=10.964 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(0, 1, 1, 12); AIC=1729.326, BIC=1745.211, Fit time=2.107 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 1, 12); AIC=1730.151, BIC=1750.008, Fit time=2.289 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=1918.650, BIC=1930.564, Fit time=0.277 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(0, 1, 2, 12); AIC=1730.150, BIC=1750.006, Fit time=3.091 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 2, 12); AIC=1732.150, BIC=1755.978, Fit time=10.156 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 1, 12); AIC=1804.444, BIC=1816.357, Fit time=1.579 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(0, 1, 1, 12); AIC=1731.325, BIC=1751.181, Fit time=3.011 seconds
# Total fit time: 48.612 seconds

# %%
print(stepwise_model.aic())
# Out:
# 1729.32551535

# %%
n_periods = 30
future_forecast = stepwise_model.predict(n_periods=n_periods)
print(future_forecast)
trainPredict2full = numpy.append(trainPredict2,future_forecast)
# Out:
# [ 216.44255631  216.37213672  216.87513152  218.15674835  218.7963469
#   219.19008616  219.61120536  219.40568983  219.35498426  219.68165461
#   220.19026908  220.09110576  220.70851309  220.37345535  220.76038858
#   221.98964558  222.60419622  222.98459747  223.39739925  223.18571885
#   223.12977132  223.45159539  223.95553325  223.85176604  224.46460069
#   224.12498361  224.50736325  225.73206912  226.34206968  226.71792131]

# %%
plt.figure(figsize=(20,10))
plt.plot(trainPredict2)
plt.plot(trainPredict2full, '--')
plt.show()
