# %%
# https://machinelearningmastery.com/time-series-prediction-lstm-recurrent-neural-networks-python-keras/
#https://pyramid-arima.readthedocs.io/en/latest/_submodules/arima.html
import numpy
from numpy import newaxis
import matplotlib.pyplot as plt
import pandas
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from pyramid.arima import auto_arima
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-32dee1efd8e1> in <module>()
#       3 import numpy
#       4 #from numpy import newaxis
# ----> 5 import matplotlib.pyplot as plt
#       6 import pandas
#       7 import math
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in <module>()
#     125 # cbook must import matplotlib only within function
#     126 # definitions, so it is safe to import from it here.
# --> 127 from . import cbook
#     128 from matplotlib.cbook import (
#     129     _backports, mplDeprecation, dedent, get_label, sanitize_sequence)
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/__init__.py in <module>()
#    2638
#    2639
# -> 2640 class _StringFuncParser(object):
#    2641     """
#    2642     A class used to convert predefined strings into
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/__init__.py in _StringFuncParser()
#    2650                                  lambda x: x,
#    2651                                  True)
# -> 2652     _funcs['quadratic'] = _FuncInfo(np.square,
#    2653                                     np.sqrt,
#    2654                                     True)
#
# AttributeError: module 'numpy' has no attribute 'square'

# %%
dataset = pandas.read_csv('NVDA.csv', usecols=[1], engine='python', skipfooter=3)
dataset = numpy.flipud(dataset)[1::]
plt.figure(figsize=(10,5))
plt.plot(dataset)
plt.show()
#dataset = dataframe.values
dataset = dataset.astype('float32')

# %%
# fix random seed for reproducibility
#numpy.random.seed(7)

# %%
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# %%
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))
# Out:
# 166 82

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
# reshape into X=t and Y=t+1
look_back = 15
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# %%
trainX.shape
# Out:
# (150, 15)

# %%
# reshape input to be [samples, time steps, features]
trainX = numpy.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = numpy.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
trainX.shape
# Out:
# (150, 1, 15)

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(64, input_shape=(1, look_back)))
model.add(Dropout(0.3))
model.add(Dense(1))
model.compile(loss='mean_absolute_error', optimizer='adam')
model.fit(trainX, trainY, epochs=200, batch_size=1, verbose=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-08ff04ba9bf9> in <module>()
#       1 # create and fit the LSTM network
#       2 model = Sequential()
# ----> 3 model.add(LSTM(64, input_shape=(1, look_back)))
#       4 model.add(Dropout(0.3))
#       5 model.add(Dense(1))
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/sequential.py in add(self, layer)
#     164                     # and create the node connecting the current layer
#     165                     # to the input layer we just created.
# --> 166                     layer(x)
#     167                     set_inputs = True
#     168                 else:
#
# ~/anaconda3/lib/python3.6/site-packages/keras/layers/recurrent.py in __call__(self, inputs, initial_state, constants, **kwargs)
#     498
#     499         if initial_state is None and constants is None:
# --> 500             return super(RNN, self).__call__(inputs, **kwargs)
#     501
#     502         # If any of `initial_state` or `constants` are specified and are Keras
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/base_layer.py in __call__(self, inputs, **kwargs)
#     458             # Actually call the layer,
#     459             # collecting output(s), mask(s), and shape(s).
# --> 460             output = self.call(inputs, **kwargs)
#     461             output_mask = self.compute_mask(inputs, previous_mask)
#     462
#
# ~/anaconda3/lib/python3.6/site-packages/keras/layers/recurrent.py in call(self, inputs, mask, training, initial_state)
#    2110                                       mask=mask,
#    2111                                       training=training,
# -> 2112                                       initial_state=initial_state)
#    2113
#    2114     @property
#
# ~/anaconda3/lib/python3.6/site-packages/keras/layers/recurrent.py in call(self, inputs, mask, training, initial_state, constants)
#     607                                              mask=mask,
#     608                                              unroll=self.unroll,
# --> 609                                              input_length=timesteps)
#     610         if self.stateful:
#     611             updates = []
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in rnn(step_function, inputs, initial_states, go_backwards, mask, constants, unroll, input_length)
#    2955             parallel_iterations=32,
#    2956             swap_memory=True,
# -> 2957             maximum_iterations=input_length)
#    2958         last_time = final_outputs[0]
#    2959         output_ta = final_outputs[1]
#
# TypeError: while_loop() got an unexpected keyword argument 'maximum_iterations'

# %%
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 4.10 RMSE
# Test Score: 6.71 RMSE

# %%
# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.figure(figsize=(20,10))
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
train2 = dataset
trainX2, trainY2 = create_dataset(train2, look_back)
trainX2 = numpy.reshape(trainX2, (trainX2.shape[0], 1, trainX2.shape[1]))
trainX2.shape, trainY2.shape
# Out:
# ((232, 1, 15), (232,))

# %%
model2 = Sequential()
model2.add(LSTM(64, input_shape=(1, look_back)))
model2.add(Dropout(0.3))
model2.add(Dense(1))
model2.compile(loss='mean_absolute_error', optimizer='adam')
model2.fit(trainX2, trainY2, epochs=200, batch_size=1, verbose=2)
# Out:
# Epoch 1/200
#  - 1s - loss: 0.0988
# Epoch 2/200
#  - 1s - loss: 0.0727
# Epoch 3/200
#  - 1s - loss: 0.0704
# Epoch 4/200
#  - 1s - loss: 0.0694
# Epoch 5/200
#  - 1s - loss: 0.0679
# Epoch 6/200
#  - 1s - loss: 0.0640
# Epoch 7/200
#  - 1s - loss: 0.0620
# Epoch 8/200
#  - 1s - loss: 0.0586
# Epoch 9/200
#  - 1s - loss: 0.0603
# Epoch 10/200
#  - 1s - loss: 0.0519
# Epoch 11/200
#  - 1s - loss: 0.0592
# Epoch 12/200
#  - 1s - loss: 0.0609
# Epoch 13/200
#  - 1s - loss: 0.0591
# Epoch 14/200
#  - 1s - loss: 0.0557
# Epoch 15/200
#  - 1s - loss: 0.0520
# Epoch 16/200
#  - 1s - loss: 0.0567
# Epoch 17/200
#  - 1s - loss: 0.0493
# Epoch 18/200
#  - 1s - loss: 0.0511
# Epoch 19/200
#  - 1s - loss: 0.0529
# Epoch 20/200
#  - 1s - loss: 0.0524
# Epoch 21/200
#  - 1s - loss: 0.0540
# Epoch 22/200
#  - 1s - loss: 0.0530
# Epoch 23/200
#  - 1s - loss: 0.0493
# Epoch 24/200
#  - 1s - loss: 0.0512
# Epoch 25/200
#  - 1s - loss: 0.0494
# Epoch 26/200
#  - 1s - loss: 0.0566
# Epoch 27/200
#  - 1s - loss: 0.0513
# Epoch 28/200
#  - 1s - loss: 0.0496
# Epoch 29/200
#  - 1s - loss: 0.0443
# Epoch 30/200
#  - 1s - loss: 0.0460
# Epoch 31/200
#  - 1s - loss: 0.0490
# Epoch 32/200
#  - 1s - loss: 0.0474
# Epoch 33/200
#  - 2s - loss: 0.0423
# Epoch 34/200
#  - 1s - loss: 0.0478
# Epoch 35/200
#  - 1s - loss: 0.0482
# Epoch 36/200
#  - 1s - loss: 0.0485
# Epoch 37/200
#  - 1s - loss: 0.0439
# Epoch 38/200
#  - 1s - loss: 0.0485
# Epoch 39/200
#  - 1s - loss: 0.0492
# Epoch 40/200
#  - 1s - loss: 0.0426
# Epoch 41/200
#  - 1s - loss: 0.0406
# Epoch 42/200
#  - 1s - loss: 0.0468
# Epoch 43/200
#  - 1s - loss: 0.0450
# Epoch 44/200
#  - 1s - loss: 0.0478
# Epoch 45/200
#  - 1s - loss: 0.0440
# Epoch 46/200
#  - 1s - loss: 0.0443
# Epoch 47/200
#  - 1s - loss: 0.0405
# Epoch 48/200
#  - 1s - loss: 0.0416
# Epoch 49/200
#  - 1s - loss: 0.0418
# Epoch 50/200
#  - 1s - loss: 0.0393
# Epoch 51/200
#  - 1s - loss: 0.0433
# Epoch 52/200
#  - 1s - loss: 0.0421
# Epoch 53/200
#  - 1s - loss: 0.0413
# Epoch 54/200
#  - 1s - loss: 0.0416
# Epoch 55/200
#  - 1s - loss: 0.0396
# Epoch 56/200
#  - 1s - loss: 0.0427
# Epoch 57/200
#  - 1s - loss: 0.0422
# Epoch 58/200
#  - 1s - loss: 0.0424
# Epoch 59/200
#  - 1s - loss: 0.0408
# Epoch 60/200
#  - 1s - loss: 0.0409
# Epoch 61/200
#  - 1s - loss: 0.0407
# Epoch 62/200
#  - 1s - loss: 0.0409
# Epoch 63/200
#  - 1s - loss: 0.0413
# Epoch 64/200
#  - 1s - loss: 0.0417
# Epoch 65/200
#  - 1s - loss: 0.0378
# Epoch 66/200
#  - 1s - loss: 0.0385
# Epoch 67/200
#  - 1s - loss: 0.0365
# Epoch 68/200
#  - 1s - loss: 0.0393
# Epoch 69/200
#  - 1s - loss: 0.0417
# Epoch 70/200
#  - 1s - loss: 0.0407
# Epoch 71/200
#  - 1s - loss: 0.0418
# Epoch 72/200
#  - 1s - loss: 0.0382
# Epoch 73/200
#  - 1s - loss: 0.0417
# Epoch 74/200
#  - 1s - loss: 0.0380
# Epoch 75/200
#  - 1s - loss: 0.0375
# Epoch 76/200
#  - 1s - loss: 0.0380
# Epoch 77/200
#  - 1s - loss: 0.0402
# Epoch 78/200
#  - 1s - loss: 0.0415
# Epoch 79/200
#  - 1s - loss: 0.0340
# Epoch 80/200
#  - 1s - loss: 0.0392
# Epoch 81/200
#  - 1s - loss: 0.0346
# Epoch 82/200
#  - 1s - loss: 0.0369
# Epoch 83/200
#  - 1s - loss: 0.0381
# Epoch 84/200
#  - 1s - loss: 0.0394
# Epoch 85/200
#  - 1s - loss: 0.0362
# Epoch 86/200
#  - 1s - loss: 0.0353
# Epoch 87/200
#  - 1s - loss: 0.0397
# Epoch 88/200
#  - 1s - loss: 0.0373
# Epoch 89/200
#  - 1s - loss: 0.0411
# Epoch 90/200
#  - 1s - loss: 0.0383
# Epoch 91/200
#  - 1s - loss: 0.0354
# Epoch 92/200
#  - 1s - loss: 0.0385
# Epoch 93/200
#  - 1s - loss: 0.0370
# Epoch 94/200
#  - 1s - loss: 0.0367
# Epoch 95/200
#  - 1s - loss: 0.0383
# Epoch 96/200
#  - 1s - loss: 0.0375
# Epoch 97/200
#  - 1s - loss: 0.0357
# Epoch 98/200
#  - 1s - loss: 0.0341
# Epoch 99/200
#  - 1s - loss: 0.0382
# Epoch 100/200
#  - 1s - loss: 0.0376
# Epoch 101/200
#  - 1s - loss: 0.0357
# Epoch 102/200
#  - 1s - loss: 0.0391
# Epoch 103/200
#  - 1s - loss: 0.0389
# Epoch 104/200
#  - 1s - loss: 0.0354
# Epoch 105/200
#  - 1s - loss: 0.0366
# Epoch 106/200
#  - 1s - loss: 0.0341
# Epoch 107/200
#  - 1s - loss: 0.0329
# Epoch 108/200
#  - 1s - loss: 0.0352
# Epoch 109/200
#  - 1s - loss: 0.0345
# Epoch 110/200
#  - 1s - loss: 0.0331
# Epoch 111/200
#  - 1s - loss: 0.0378
# Epoch 112/200
#  - 1s - loss: 0.0363
# Epoch 113/200
#  - 1s - loss: 0.0360
# Epoch 114/200
#  - 1s - loss: 0.0313
# Epoch 115/200
#  - 1s - loss: 0.0346
# Epoch 116/200
#  - 1s - loss: 0.0369
# Epoch 117/200
#  - 1s - loss: 0.0384
# Epoch 118/200
#  - 1s - loss: 0.0367
# Epoch 119/200
#  - 1s - loss: 0.0373
# Epoch 120/200
#  - 1s - loss: 0.0338
# Epoch 121/200
#  - 1s - loss: 0.0351
# Epoch 122/200
#  - 1s - loss: 0.0356
# Epoch 123/200
#  - 1s - loss: 0.0371
# Epoch 124/200
#  - 1s - loss: 0.0365
# Epoch 125/200
#  - 1s - loss: 0.0322
# Epoch 126/200
#  - 1s - loss: 0.0351
# Epoch 127/200
#  - 1s - loss: 0.0332
# Epoch 128/200
#  - 1s - loss: 0.0337
# Epoch 129/200
#  - 1s - loss: 0.0334
# Epoch 130/200
#  - 1s - loss: 0.0349
# Epoch 131/200
#  - 1s - loss: 0.0326
# Epoch 132/200
#  - 1s - loss: 0.0313
# Epoch 133/200
#  - 1s - loss: 0.0365
# Epoch 134/200
#  - 1s - loss: 0.0337
# Epoch 135/200
#  - 1s - loss: 0.0341
# Epoch 136/200
#  - 1s - loss: 0.0341
# Epoch 137/200
#  - 1s - loss: 0.0384
# Epoch 138/200
#  - 1s - loss: 0.0345
# Epoch 139/200
#  - 1s - loss: 0.0359
# Epoch 140/200
#  - 1s - loss: 0.0348
# Epoch 141/200
#  - 1s - loss: 0.0318
# Epoch 142/200
#  - 1s - loss: 0.0360
# Epoch 143/200
#  - 1s - loss: 0.0365
# Epoch 144/200
#  - 1s - loss: 0.0344
# Epoch 145/200
#  - 1s - loss: 0.0355
# Epoch 146/200
#  - 1s - loss: 0.0334
# Epoch 147/200
#  - 1s - loss: 0.0347
# Epoch 148/200
#  - 1s - loss: 0.0329
# Epoch 149/200
#  - 1s - loss: 0.0319
# Epoch 150/200
#  - 1s - loss: 0.0349
# Epoch 151/200
#  - 1s - loss: 0.0374
# Epoch 152/200
#  - 1s - loss: 0.0376
# Epoch 153/200
#  - 1s - loss: 0.0339
# Epoch 154/200
#  - 1s - loss: 0.0332
# Epoch 155/200
#  - 1s - loss: 0.0339
# Epoch 156/200
#  - 1s - loss: 0.0335
# Epoch 157/200
#  - 1s - loss: 0.0335
# Epoch 158/200
#  - 1s - loss: 0.0358
# Epoch 159/200
#  - 1s - loss: 0.0359
# Epoch 160/200
#  - 1s - loss: 0.0324
# Epoch 161/200
#  - 1s - loss: 0.0330
# Epoch 162/200
#  - 1s - loss: 0.0346
# Epoch 163/200
#  - 1s - loss: 0.0351
# Epoch 164/200
#  - 1s - loss: 0.0322
# Epoch 165/200
#  - 1s - loss: 0.0329
# Epoch 166/200
#  - 1s - loss: 0.0328
# Epoch 167/200
#  - 1s - loss: 0.0356
# Epoch 168/200
#  - 1s - loss: 0.0342
# Epoch 169/200
#  - 1s - loss: 0.0327
# Epoch 170/200
#  - 1s - loss: 0.0316
# Epoch 171/200
#  - 1s - loss: 0.0325
# Epoch 172/200
#  - 1s - loss: 0.0324
# Epoch 173/200
#  - 1s - loss: 0.0364
# Epoch 174/200
#  - 1s - loss: 0.0356
# Epoch 175/200
#  - 1s - loss: 0.0321
# Epoch 176/200
#  - 1s - loss: 0.0331
# Epoch 177/200
#  - 1s - loss: 0.0356
# Epoch 178/200
#  - 1s - loss: 0.0324
# Epoch 179/200
#  - 1s - loss: 0.0308
# Epoch 180/200
#  - 1s - loss: 0.0331
# Epoch 181/200
#  - 1s - loss: 0.0321
# Epoch 182/200
#  - 1s - loss: 0.0306
# Epoch 183/200
#  - 1s - loss: 0.0311
# Epoch 184/200
#  - 1s - loss: 0.0341
# Epoch 185/200
#  - 1s - loss: 0.0351
# Epoch 186/200
#  - 1s - loss: 0.0343
# Epoch 187/200
#  - 1s - loss: 0.0353
# Epoch 188/200
#  - 1s - loss: 0.0320
# Epoch 189/200
#  - 1s - loss: 0.0324
# Epoch 190/200
#  - 1s - loss: 0.0358
# Epoch 191/200
#  - 1s - loss: 0.0338
# Epoch 192/200
#  - 1s - loss: 0.0358
# Epoch 193/200
#  - 1s - loss: 0.0317
# Epoch 194/200
#  - 1s - loss: 0.0319
# Epoch 195/200
#  - 1s - loss: 0.0314
# Epoch 196/200
#  - 1s - loss: 0.0329
# Epoch 197/200
#  - 1s - loss: 0.0305
# Epoch 198/200
#  - 1s - loss: 0.0345
# Epoch 199/200
#  - 1s - loss: 0.0349
# Epoch 200/200
#  - 1s - loss: 0.0353

# %%
# make predictions
trainPredict2 = model2.predict(trainX2)
# invert predictions
trainPredict2 = scaler.inverse_transform(trainPredict2)
trainY2 = scaler.inverse_transform([trainY2])
# calculate root mean squared error
trainScore2 = math.sqrt(mean_squared_error(trainY2, trainPredict2.T))
print('Train Score2: %.2f RMSE' % (trainScore2))
# Out:
# Train Score2: 4.83 RMSE

# %%
trainY2.shape, trainPredict2.shape
# Out:
# ((1, 232), (232, 1))

# %%
# shift train predictions for plotting
trainPredictPlot2 = numpy.empty_like(dataset)
trainPredictPlot2[:, :] = numpy.nan
trainPredictPlot2[look_back:len(trainPredict2)+look_back, :] = trainPredict2

# plot baseline and predictions
plt.figure(figsize=(20,10))
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot2)
plt.show()

# %%
import pandas as pd
#from plotly.plotly import plot_mpl
#from statsmodels.tsa.seasonal import seasonal_decompose

# %%
#trainPredict2 = pd.DataFrame(trainPredict2)
#result = seasonal_decompose(trainPredict2, model='multiplicative')
#fig = result.plot()
#plot_mpl(fig)

# %%
numpy.savetxt("LSTM_Predicted.csv", trainPredict2, delimiter=",")

# %%
stepwise_model = auto_arima(trainPredict2, start_p=1, start_q=1,
                           max_p=3, max_q=3, m=7,
                           start_P=0, seasonal=True,
                           d=1, D=1, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
# Out:
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 7); AIC=1148.696, BIC=1165.930, Fit time=1.074 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 7); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 7); AIC=1216.058, BIC=1229.845, Fit time=0.293 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 7); AIC=1150.272, BIC=1164.059, Fit time=0.829 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 1, 7); AIC=1146.461, BIC=1167.142, Fit time=1.553 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 0, 7); AIC=1218.003, BIC=1235.237, Fit time=0.353 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 2, 7); AIC=1148.493, BIC=1172.620, Fit time=2.718 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 0, 7); AIC=1301.414, BIC=1315.201, Fit time=0.268 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(2, 1, 2, 7); AIC=1150.478, BIC=1178.052, Fit time=1.112 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 1, 7); AIC=1147.841, BIC=1165.074, Fit time=0.865 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(1, 1, 1, 7); AIC=1148.407, BIC=1172.534, Fit time=1.698 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 1, 7); AIC=1144.925, BIC=1162.159, Fit time=0.755 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(0, 1, 1, 7); AIC=1147.285, BIC=1161.072, Fit time=0.745 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(2, 1, 1, 7); AIC=1146.905, BIC=1167.586, Fit time=1.942 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 2, 7); AIC=1146.940, BIC=1167.621, Fit time=2.441 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(0, 1, 0, 7); AIC=1300.543, BIC=1310.883, Fit time=0.164 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(2, 1, 2, 7); AIC=1148.948, BIC=1173.075, Fit time=0.787 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(1, 1, 1, 7); AIC=1163.937, BIC=1177.724, Fit time=0.661 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(1, 1, 1, 7); AIC=1146.407, BIC=1167.087, Fit time=1.058 seconds
# Total fit time: 19.323 seconds

# %%
print(stepwise_model.aic())
# Out:
# 1144.92521428

# %%
n_periods = 15
future_forecast = stepwise_model.predict(n_periods=n_periods)
print(future_forecast)
trainPredict2full = numpy.append(trainPredict2,future_forecast)
# Out:
# [ 216.50837448  216.56739417  217.17816905  216.7814557   215.87606612
#   216.73973092  215.98579912  215.75002525  216.4130119   216.23067284
#   216.32256716  215.65861627  215.73733921  214.46720572  214.09280461]

# %%
plt.figure(figsize=(20,10))
plt.plot(trainPredict2)
plt.plot(trainPredict2full, '--')
plt.show()
