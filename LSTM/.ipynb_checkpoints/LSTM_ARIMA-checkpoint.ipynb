# %%
# https://machinelearningmastery.com/time-series-prediction-lstm-recurrent-neural-networks-python-keras/
import numpy
from numpy import newaxis
import matplotlib.pyplot as plt
import pandas
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from pyramid.arima import auto_arima

# %%
dataset = pandas.read_csv('HistoricalQuotes.csv', usecols=[1], engine='python', skipfooter=3)
dataset = numpy.flipud(dataset)[850::]
plt.figure(figsize=(10,5))
plt.plot(dataset)
plt.show()

# %%
# fix random seed for reproducibility
numpy.random.seed(7)

# %%
# load the dataset
dataset = pandas.read_csv('HistoricalQuotes.csv', usecols=[1], engine='python', skipfooter=3)
dataset = numpy.flipud(dataset)[850::]
#dataset = dataframe.values
dataset = dataset.astype('float32')

# %%
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# %%
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))
# Out:
# 273 135

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
# reshape into X=t and Y=t+1
look_back = 15
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# %%
trainX.shape
# Out:
# (257, 15)

# %%
# reshape input to be [samples, time steps, features]
trainX = numpy.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = numpy.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
trainX.shape
# Out:
# (257, 1, 15)

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(30, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=50, batch_size=1, verbose=2)
# Out:
# Epoch 1/50
#  - 3s - loss: 0.0132
# Epoch 2/50
#  - 0s - loss: 0.0019
# Epoch 3/50
#  - 0s - loss: 0.0016
# Epoch 4/50
#  - 0s - loss: 0.0014
# Epoch 5/50
#  - 0s - loss: 0.0013
# Epoch 6/50
#  - 1s - loss: 0.0011
# Epoch 7/50
#  - 0s - loss: 0.0010
# Epoch 8/50
#  - 0s - loss: 8.4397e-04
# Epoch 9/50
#  - 0s - loss: 8.8465e-04
# Epoch 10/50
#  - 0s - loss: 7.3777e-04
# Epoch 11/50
#  - 0s - loss: 7.2190e-04
# Epoch 12/50
#  - 0s - loss: 7.2750e-04
# Epoch 13/50
#  - 0s - loss: 7.0834e-04
# Epoch 14/50
#  - 1s - loss: 6.3687e-04
# Epoch 15/50
#  - 0s - loss: 6.3989e-04
# Epoch 16/50
#  - 0s - loss: 5.9434e-04
# Epoch 17/50
#  - 1s - loss: 7.0347e-04
# Epoch 18/50
#  - 0s - loss: 6.1173e-04
# Epoch 19/50
#  - 0s - loss: 5.6172e-04
# Epoch 20/50
#  - 0s - loss: 5.8115e-04
# Epoch 21/50
#  - 1s - loss: 5.6620e-04
# Epoch 22/50
#  - 1s - loss: 6.2477e-04
# Epoch 23/50
#  - 0s - loss: 5.2156e-04
# Epoch 24/50
#  - 0s - loss: 5.5825e-04
# Epoch 25/50
#  - 1s - loss: 5.4943e-04
# Epoch 26/50
#  - 0s - loss: 5.4650e-04
# Epoch 27/50
#  - 0s - loss: 5.2878e-04
# Epoch 28/50
#  - 0s - loss: 6.2598e-04
# Epoch 29/50
#  - 0s - loss: 5.2118e-04
# Epoch 30/50
#  - 0s - loss: 5.7933e-04
# Epoch 31/50
#  - 0s - loss: 5.8071e-04
# Epoch 32/50
#  - 1s - loss: 4.9996e-04
# Epoch 33/50
#  - 0s - loss: 4.8568e-04
# Epoch 34/50
#  - 0s - loss: 5.7527e-04
# Epoch 35/50
#  - 0s - loss: 5.1554e-04
# Epoch 36/50
#  - 0s - loss: 6.4520e-04
# Epoch 37/50
#  - 0s - loss: 4.8265e-04
# Epoch 38/50
#  - 0s - loss: 4.6213e-04
# Epoch 39/50
#  - 0s - loss: 5.1737e-04
# Epoch 40/50
#  - 0s - loss: 5.5471e-04
# Epoch 41/50
#  - 0s - loss: 5.2102e-04
# Epoch 42/50
#  - 0s - loss: 4.8906e-04
# Epoch 43/50
#  - 0s - loss: 5.0906e-04
# Epoch 44/50
#  - 1s - loss: 5.1769e-04
# Epoch 45/50
#  - 0s - loss: 4.5077e-04
# Epoch 46/50
#  - 1s - loss: 4.1662e-04
# Epoch 47/50
#  - 0s - loss: 4.8968e-04
# Epoch 48/50
#  - 0s - loss: 4.7937e-04
# Epoch 49/50
#  - 0s - loss: 4.7187e-04
# Epoch 50/50
#  - 0s - loss: 4.8493e-04

# %%
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 4.26 RMSE
# Test Score: 6.15 RMSE

# %%
# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.figure(figsize=(20,10))
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
train2 = dataset
trainX2, trainY2 = create_dataset(train2, look_back)
trainX2 = numpy.reshape(trainX2, (trainX2.shape[0], 1, trainX2.shape[1]))
trainX2.shape, trainY2.shape
# Out:
# ((392, 1, 15), (392,))

# %%
model2 = Sequential()
model2.add(LSTM(4, input_shape=(1, look_back)))
model2.add(Dense(1))
model2.compile(loss='mean_squared_error', optimizer='adam')
model2.fit(trainX2, trainY2, epochs=50, batch_size=1, verbose=2)
# Out:
# Epoch 1/50
#  - 3s - loss: 0.0451
# Epoch 2/50
#  - 1s - loss: 0.0024
# Epoch 3/50
#  - 1s - loss: 0.0020
# Epoch 4/50
#  - 1s - loss: 0.0020
# Epoch 5/50
#  - 1s - loss: 0.0019
# Epoch 6/50
#  - 1s - loss: 0.0018
# Epoch 7/50
#  - 1s - loss: 0.0016
# Epoch 8/50
#  - 1s - loss: 0.0016
# Epoch 9/50
#  - 1s - loss: 0.0015
# Epoch 10/50
#  - 1s - loss: 0.0014
# Epoch 11/50
#  - 1s - loss: 0.0013
# Epoch 12/50
#  - 1s - loss: 0.0012
# Epoch 13/50
#  - 1s - loss: 0.0012
# Epoch 14/50
#  - 1s - loss: 0.0011
# Epoch 15/50
#  - 1s - loss: 0.0010
# Epoch 16/50
#  - 1s - loss: 0.0011
# Epoch 17/50
#  - 1s - loss: 0.0010
# Epoch 18/50
#  - 1s - loss: 9.5774e-04
# Epoch 19/50
#  - 1s - loss: 8.9566e-04
# Epoch 20/50
#  - 1s - loss: 8.8020e-04
# Epoch 21/50
#  - 1s - loss: 8.5390e-04
# Epoch 22/50
#  - 1s - loss: 8.4685e-04
# Epoch 23/50
#  - 1s - loss: 8.6471e-04
# Epoch 24/50
#  - 1s - loss: 8.8556e-04
# Epoch 25/50
#  - 1s - loss: 8.3683e-04
# Epoch 26/50
#  - 1s - loss: 9.2139e-04
# Epoch 27/50
#  - 1s - loss: 8.0767e-04
# Epoch 28/50
#  - 1s - loss: 8.9331e-04
# Epoch 29/50
#  - 1s - loss: 7.7841e-04
# Epoch 30/50
#  - 1s - loss: 8.0352e-04
# Epoch 31/50
#  - 1s - loss: 8.9809e-04
# Epoch 32/50
#  - 1s - loss: 7.6518e-04
# Epoch 33/50
#  - 1s - loss: 7.9037e-04
# Epoch 34/50
#  - 1s - loss: 7.4461e-04
# Epoch 35/50
#  - 1s - loss: 7.6667e-04
# Epoch 36/50
#  - 1s - loss: 7.5678e-04
# Epoch 37/50
#  - 1s - loss: 7.5013e-04
# Epoch 38/50
#  - 1s - loss: 6.9473e-04
# Epoch 39/50
#  - 1s - loss: 7.6181e-04
# Epoch 40/50
#  - 1s - loss: 7.6167e-04
# Epoch 41/50
#  - 1s - loss: 8.4568e-04
# Epoch 42/50
#  - 1s - loss: 7.3066e-04
# Epoch 43/50
#  - 1s - loss: 7.4409e-04
# Epoch 44/50
#  - 1s - loss: 7.3727e-04
# Epoch 45/50
#  - 1s - loss: 7.1957e-04
# Epoch 46/50
#  - 1s - loss: 7.2010e-04
# Epoch 47/50
#  - 1s - loss: 6.8045e-04
# Epoch 48/50
#  - 1s - loss: 7.5621e-04
# Epoch 49/50
#  - 1s - loss: 6.7560e-04
# Epoch 50/50
#  - 1s - loss: 6.8417e-04

# %%
trainY2.shape, trainPredict2.shape
# Out:
# ((392,), (392, 1))

# %%
# make predictions
trainPredict2 = model2.predict(trainX2)
# invert predictions
trainPredict2 = scaler.inverse_transform(trainPredict2)
trainY2 = scaler.inverse_transform([trainY2])
# calculate root mean squared error
trainScore2 = math.sqrt(mean_squared_error(trainY2, trainPredict2.T))
print('Train Score2: %.2f RMSE' % (trainScore2))
# Out:
# Train Score2: 5.56 RMSE

# %%
# shift train predictions for plotting
trainPredictPlot2 = numpy.empty_like(dataset)
trainPredictPlot2[:, :] = numpy.nan
trainPredictPlot2[look_back:len(trainPredict2)+look_back, :] = trainPredict2

# plot baseline and predictions
plt.figure(figsize=(20,10))
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot2)
plt.show()

# %%
import pandas as pd
#from plotly.plotly import plot_mpl
#from statsmodels.tsa.seasonal import seasonal_decompose

# %%
#trainPredict2 = pd.DataFrame(trainPredict2)
#result = seasonal_decompose(trainPredict2, model='multiplicative')
#fig = result.plot()
#plot_mpl(fig)

# %%
numpy.savetxt("LSTM_Predicted.csv", trainPredict2, delimiter=",")

# %%
stepwise_model = auto_arima(trainPredict2, start_p=1, start_q=1,
                           max_p=3, max_q=3, m=12,
                           start_P=0, seasonal=True,
                           d=1, D=1, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
# Out:
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=1741.799, BIC=1761.656, Fit time=1.881 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=1877.522, BIC=1893.407, Fit time=0.347 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=1768.803, BIC=1784.688, Fit time=0.886 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=1715.182, BIC=1739.010, Fit time=2.068 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 0, 12); AIC=1867.559, BIC=1887.416, Fit time=1.460 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=1768.725, BIC=1796.524, Fit time=4.753 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=2033.243, BIC=2049.128, Fit time=0.473 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(2, 1, 2, 12); AIC=1769.418, BIC=1801.188, Fit time=5.171 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=1748.680, BIC=1768.536, Fit time=1.062 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=1726.313, BIC=1754.112, Fit time=1.930 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 1, 12); AIC=1723.605, BIC=1743.461, Fit time=1.297 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 1, 12); AIC=1689.124, BIC=1716.923, Fit time=1.737 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(1, 1, 1, 12); AIC=nan, BIC=nan, Fit time=0.246 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=1715.541, BIC=1739.368, Fit time=1.924 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(2, 1, 1, 12); AIC=1690.948, BIC=1722.718, Fit time=3.688 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 0, 12); AIC=1838.591, BIC=1862.418, Fit time=0.557 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=1691.192, BIC=1722.962, Fit time=4.632 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 0, 12); AIC=2009.123, BIC=2028.980, Fit time=0.258 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(2, 1, 2, 12); AIC=1690.281, BIC=1726.022, Fit time=5.579 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(1, 1, 1, 12); AIC=1710.070, BIC=1733.897, Fit time=1.495 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 1, 1, 12); AIC=1686.915, BIC=1718.685, Fit time=1.386 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(1, 1, 1, 12); AIC=nan, BIC=nan, Fit time=0.258 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=1713.802, BIC=1741.601, Fit time=1.824 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(2, 1, 1, 12); AIC=1688.833, BIC=1724.574, Fit time=4.621 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 1, 0, 12); AIC=1834.710, BIC=1862.509, Fit time=1.808 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=1688.936, BIC=1724.677, Fit time=5.561 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 1, 0, 12); AIC=2007.059, BIC=2030.886, Fit time=0.884 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(2, 1, 2, 12); AIC=1687.561, BIC=1727.273, Fit time=6.292 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(1, 1, 1, 12); AIC=1667.919, BIC=1703.660, Fit time=2.485 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=1695.306, BIC=1727.076, Fit time=2.176 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=1692.600, BIC=1724.370, Fit time=2.199 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(2, 1, 1, 12); AIC=1669.734, BIC=1709.446, Fit time=5.457 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(1, 1, 0, 12); AIC=1806.570, BIC=1838.340, Fit time=2.354 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=1670.238, BIC=1709.950, Fit time=6.508 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(0, 1, 0, 12); AIC=1973.646, BIC=2001.445, Fit time=0.981 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(2, 1, 2, 12); AIC=1668.953, BIC=1712.637, Fit time=6.718 seconds
# Total fit time: 92.967 seconds

# %%
print(stepwise_model.aic())
# Out:
# 1667.918745

# %%
n_periods = 30
future_forecast = stepwise_model.predict(n_periods=n_periods)
print(future_forecast)
trainPredict2full = numpy.append(trainPredict2,future_forecast)
# Out:
# [ 222.04324057  221.80118744  223.56809823  225.38398896  226.41550457
#   228.10806453  228.96605575  230.7451775   232.17154745  232.2019253
#   234.2313437   233.34435378  233.52757951  233.73297084  233.8659724
#   234.65385074  235.0390208   235.48038469  236.05237076  235.57148531
#   235.62729633  235.95180919  235.56057409  236.1217777   236.5053798
#   236.55410381  237.18137244  238.22614631  238.7418068   239.53463007]

# %%
plt.figure(figsize=(20,10))
plt.plot(trainPredict2)
plt.plot(trainPredict2full, '--')
plt.show()
